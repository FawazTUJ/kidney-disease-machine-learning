# %%
import numpy as np
np.set_printoptions(threshold=np.inf)
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('kidney_disease.csv')
data
# Out:
#       id   age    bp     sg   al   su     rbc          ba    bgr    bu    wc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN  notpresent  121.0  36.0  7800
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN  notpresent    NaN  18.0  6000
# 2      2  62.0  80.0  1.010  2.0  3.0  normal  notpresent  423.0  53.0  7500
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  notpresent  117.0  56.0  6700
# 4      4  51.0  80.0  1.010  2.0  0.0  normal  notpresent  106.0  26.0  7300
# ..   ...   ...   ...    ...  ...  ...     ...         ...    ...   ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  notpresent  140.0  49.0  6700
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  notpresent   75.0  31.0  7800
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  notpresent  100.0  26.0  6600
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  notpresent  114.0  50.0  7200
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  notpresent  131.0  18.0  6800
#
# ...

# %%
data.drop(['id'], axis = 'columns', inplace = True)

# %%
data
# Out:
#       age    bp     sg   al   su     rbc          ba    bgr    bu    wc   rc  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN  notpresent  121.0  36.0  7800  5.2
# 1     7.0  50.0  1.020  4.0  0.0     NaN  notpresent    NaN  18.0  6000  NaN
# 2    62.0  80.0  1.010  2.0  3.0  normal  notpresent  423.0  53.0  7500  NaN
# 3    48.0  70.0  1.005  4.0  0.0  normal  notpresent  117.0  56.0  6700  3.9
# 4    51.0  80.0  1.010  2.0  0.0  normal  notpresent  106.0  26.0  7300  4.6
# ..    ...   ...    ...  ...  ...     ...         ...    ...   ...   ...  ...
# 395  55.0  80.0  1.020  0.0  0.0  normal  notpresent  140.0  49.0  6700  4.9
# 396  42.0  70.0  1.025  0.0  0.0  normal  notpresent   75.0  31.0  7800  6.2
# 397  12.0  80.0  1.020  0.0  0.0  normal  notpresent  100.0  26.0  6600  5.4
# 398  17.0  60.0  1.025  0.0  0.0  normal  notpresent  114.0  50.0  7200  5.9
# 399  58.0  80.0  1.025  0.0  0.0  normal  notpresent  131.0  18.0  6800  6.1
#
# ...

# %%
data.isnull().sum()
# Out:
# age                 8
# bp                 12
# sg                 33
# al                 32
# su                 37
# rbc               104
# ba                  0
# bgr                32
# bu                 13
# wc                 76
# rc                114
# htn                 1
# dm                  1
# cad                 1
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
i=SimpleImputer()
i = i.fit(data[['age']])
data[['age']] = i.transform(data[['age']])

i = i.fit(data[['bp']])
data[['bp']]=i.transform(data[['bp']])

i = i.fit(data[['sg']])
data[['sg']]=i.transform(data[['sg']])

i = i.fit(data[['al']])
data[['al']]=i.transform(data[['al']])

i = i.fit(data[['su']])
data[['su']]=i.transform(data[['su']])

i = i.fit(data[['bgr']])
data[['bgr']]=i.transform(data[['bgr']])

i = i.fit(data[['bu']])
data[['bu']]=i.transform(data[['bu']])


#i = i.fit(data[['rc']])
#data[['rc']]=i.transform(data[['rc']])
data.isnull().sum()
# Out:
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               104
# ba                  0
# bgr                 0
# bu                  0
# wc                 76
# rc                114
# htn                 1
# dm                  1
# cad                 1
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
data= data.dropna(axis=0)
data
# Out:
#       age          bp     sg   al   su       rbc          ba    bgr     bu  \
# 3    48.0   70.000000  1.005  4.0  0.0    normal  notpresent  117.0   56.0
# 4    51.0   80.000000  1.010  2.0  0.0    normal  notpresent  106.0   26.0
# 7    24.0   76.469072  1.015  2.0  4.0    normal  notpresent  410.0   31.0
# 8    52.0  100.000000  1.015  3.0  0.0    normal  notpresent  138.0   60.0
# 9    53.0   90.000000  1.020  2.0  0.0  abnormal  notpresent   70.0  107.0
# ..    ...         ...    ...  ...  ...       ...         ...    ...    ...
# 395  55.0   80.000000  1.020  0.0  0.0    normal  notpresent  140.0   49.0
# 396  42.0   70.000000  1.025  0.0  0.0    normal  notpresent   75.0   31.0
# 397  12.0   80.000000  1.020  0.0  0.0    normal  notpresent  100.0   26.0
# 398  17.0   60.000000  1.025  0.0  0.0    normal  notpresent  114.0   50.0
# 399  58.0   80.000000  1.025  0.0  0.0    normal  notpresent  131.0   18.0
#
#         wc   rc  htn   dm cad appet   pe  ane  classification
# ...

# %%
#scaling values
from sklearn.preprocessing import MinMaxScaler

import joblib
scaler = MinMaxScaler()

# %%
scaler.fit(data[['age']])
data['age'] = scaler.transform(data[['age']])
joblib.dump(scaler,'kidney_age.gz')


scaler.fit(data[['bp']])
data['bp'] = scaler.transform(data[['bp']])
joblib.dump(scaler,'kidney_bp.gz')

scaler.fit(data[['sg']])
data['sg'] = scaler.transform(data[['sg']])
joblib.dump(scaler,'kidney_sg.gz')

scaler.fit(data[['al']])
data['al'] = scaler.transform(data[['al']])
joblib.dump(scaler,'kidney_al.gz')

scaler.fit(data[['su']])
data['su'] = scaler.transform(data[['su']])
joblib.dump(scaler,'kidney_su.gz')

scaler.fit(data[['bgr']])
data['bgr']=scaler.transform(data[['bgr']])
joblib.dump(scaler,'kidney_bgr.gz')

scaler.fit(data[['bu']])
data['bu']=scaler.transform(data[['bu']])
joblib.dump(scaler,'kidney_bu.gz')

scaler.fit(data[['wc']])
data['wc']=scaler.transform(data[['wc']])
joblib.dump(scaler,'kidney_wc.gz')

scaler.fit(data[['rc']])
data['rc']=scaler.transform(data[['rc']])
joblib.dump(scaler,'kidney_rc.gz')
data
# Out:
# C:\Users\Fawaz_Tujjar\AppData\Local\Temp\ipykernel_10712\2145946605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['age'] = scaler.transform(data[['age']])
# C:\Users\Fawaz_Tujjar\AppData\Local\Temp\ipykernel_10712\2145946605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bp'] = scaler.transform(data[['bp']])
# C:\Users\Fawaz_Tujjar\AppData\Local\Temp\ipykernel_10712\2145946605.py:11: SettingWithCopyWarning:
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l1= LabelEncoder()
l1.fit(data['rbc'])
data['rbc']=l1.transform(data[['rbc']])
joblib.dump(l1,'kidney_rbc.gz')

l1.fit(data['ba'])
data['ba']=l1.transform(data[['ba']])
joblib.dump(l1,'kidney_ba.gz')

l1.fit(data['htn'])
data['htn']=l1.transform(data[['htn']])
joblib.dump(l1,'kidney_htn.gz')

l1.fit(data['dm'])
data['dm']=l1.transform(data[['dm']])
joblib.dump(l1,'kidney_dm.gz')

l1.fit(data['cad'])
data['cad']=l1.transform(data[['cad']])
joblib.dump(l1,'kidney_cad.gz')

l1.fit(data['appet'])
data['appet']=l1.transform(data[['appet']])
joblib.dump(l1,'kidney_appet.gz')

l1.fit(data['pe'])
data['pe']=l1.transform(data[['pe']])
joblib.dump(l1,'kidney_pe.gz')

l1.fit(data['ane'])
data['ane']=l1.transform(data[['ane']])
joblib.dump(l1,'kideny_ane.gz')
data
# Out:
# C:\Users\Fawaz_Tujjar\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Fawaz_Tujjar\AppData\Local\Temp\ipykernel_10712\2433096757.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rbc']=l1.transform(data[['rbc']])
# C:\Users\Fawaz_Tujjar\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
X=data.loc[: , data.columns != 'classification']
X.head()
# Out:
#         age        bp        sg        al   su  rbc  ba       bgr        bu  \
# 3  0.545455  0.333333  0.023810  0.666667  0.0    1   0  0.111905  0.147436
# 4  0.584416  0.500000  0.047619  0.333333  0.0    1   0  0.085714  0.051282
# 7  0.233766  0.441151  0.071429  0.333333  0.8    1   0  0.809524  0.067308
# 8  0.597403  0.833333  0.071429  0.500000  0.0    1   0  0.161905  0.160256
# 9  0.610390  0.666667  0.095238  0.333333  0.0    0   0  0.000000  0.310897
#
#          wc        rc  htn  dm  cad  appet  pe  ane
# 3  0.187629  0.305085    1   2    1      1   1    1
# 4  0.212371  0.423729    0   2    1      0   0    0
# 7  0.195876  0.491525    0   3    1      0   1    0
# 8  0.307216  0.322034    1   3    1      0   0    1
# 9  0.410309  0.271186    1   3    1      1   0    1

# %%
y=data['classification']
y
# Out:
# 3      1
# 4      1
# 7      1
# 8      1
# 9      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: classification, Length: 240, dtype: int64

# %%
# Checking if Data is balanced
xs = data['classification'].value_counts().index
ys = data['classification'].value_counts().values

ax = sns.barplot(xs,ys)
ax.set_xlabel("kidney disease")
plt.show()
# Out:
# C:\Users\Fawaz_Tujjar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # To balance the data

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2) 
X, y = sm.fit_resample(X, y)

# %%
X
# Out:
#           age        bp        sg        al   su  rbc  ba       bgr        bu  \
# 0    0.545455  0.333333  0.023810  0.666667  0.0    1   0  0.111905  0.147436
# 1    0.584416  0.500000  0.047619  0.333333  0.0    1   0  0.085714  0.051282
# 2    0.233766  0.441151  0.071429  0.333333  0.8    1   0  0.809524  0.067308
# 3    0.597403  0.833333  0.071429  0.500000  0.0    1   0  0.161905  0.160256
# 4    0.610390  0.666667  0.095238  0.333333  0.0    0   0  0.000000  0.310897
# ..        ...       ...       ...       ...  ...  ...  ..       ...       ...
# 285  0.482432  0.779410  0.055322  0.107847  0.0    0   0  0.170671  0.120101
# 286  0.518468  0.500000  0.106679  0.623376  0.0    0   0  0.047773  0.489552
# 287  0.552566  0.397815  0.062217  0.333333  0.0    0   0  0.075496  0.090584
# 288  0.476464  0.527997  0.071429  0.472003  0.0    0   0  0.035484  0.457567
# 289  0.468909  0.631626  0.071429  0.500000  0.0    0   0  0.033089  0.531899
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,train_size=0.8)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (232, 17) (232,)
# Test set: (58, 17) (58,)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(solver='liblinear').fit(X_train,y_train)
clf
# Out:
# LogisticRegression(solver='liblinear')

# %%
X_test
# Out:
#           age        bp        sg        al        su  rbc  ba       bgr  \
# 288  0.476464  0.527997  0.071429  0.472003  0.000000    0   0  0.035484
# 259  0.515903  0.404591  0.071429  0.786227  0.457963    0   0  0.037456
# 227  0.116883  0.500000  0.119048  0.000000  0.000000    1   0  0.054762
# 284  0.759377  0.417333  0.071429  0.416000  0.099200    0   0  0.286571
# 149  0.584416  0.166667  0.095238  0.000000  0.000000    1   0  0.140476
# 181  0.740260  0.333333  0.119048  0.000000  0.000000    1   0  0.142857
# 35   0.532468  0.833333  0.047619  0.000000  0.000000    0   0  0.319048
# 185  0.207792  0.166667  0.119048  0.000000  0.000000    1   0  0.064286
# 40   0.740260  0.500000  0.047619  0.333333  0.400000    1   0  0.185113
# 138  0.363636  0.166667  0.095238  0.000000  0.000000    1   0  0.050000
# 109  0.467532  0.500000  0.095238  0.000000  0.000000    1   0  0.147619
# 237  0.077922  0.500000  0.095238  0.000000  0.000000    1   0  0.071429
# ...

# %%
y_predict_prob = clf.predict_proba(X_test)
y_predict_prob
# Out:
# array([[1.00354304e-02, 9.89964570e-01],
#        [1.32577727e-02, 9.86742227e-01],
#        [9.19800293e-01, 8.01997070e-02],
#        [1.47073140e-03, 9.98529269e-01],
#        [9.37273881e-01, 6.27261191e-02],
#        [9.01485069e-01, 9.85149309e-02],
#        [2.42907139e-02, 9.75709286e-01],
#        [9.51220505e-01, 4.87794954e-02],
#        [2.84557148e-01, 7.15442852e-01],
#        [9.18011907e-01, 8.19880935e-02],
#        [8.93030258e-01, 1.06969742e-01],
#        [9.21111089e-01, 7.88889112e-02],
#        [9.38033393e-01, 6.19666065e-02],
#        [5.44903573e-03, 9.94550964e-01],
#        [9.18520461e-01, 8.14795394e-02],
#        [9.28101140e-01, 7.18988597e-02],
#        [1.59457013e-02, 9.84054299e-01],
#        [4.15042653e-02, 9.58495735e-01],
#        [9.25651713e-01, 7.43482869e-02],
#        [9.33780866e-04, 9.99066219e-01],
#        [9.17848630e-01, 8.21513701e-02],
#        [4.54153154e-01, 5.45846846e-01],
#        [9.34607460e-01, 6.53925396e-02],
# ...

# %%
print('Accuracy of Logistic regression classifier on train set:' , clf.score(X_train, y_train))
print('Accuracy of Logistic regression classifier on test set:' , clf.score(X_test, y_test))
# Out:
# Accuracy of Logistic regression classifier on train set: 0.9698275862068966
# Accuracy of Logistic regression classifier on test set: 1.0

# %%
array = np.arange(6).reshape(1,6)
array = array.astype(np.float64)

# %%
array[0][0]=0.1
array[0][1]=0.339530
array[0][2]=0.2
array[0][3]=0.1
array[0][4]=0.8
array[0][5]=0.42
array
# Out:
# array([[0.1    , 0.33953, 0.2    , 0.1    , 0.8    , 0.42   ]])

# %%
from sklearn.decomposition import PCA 
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix,precision_recall_curve, roc_curve
import seaborn as sea

# %% [markdown]
# # Supervised learning_SVM

# %%
#Supervised learning_SVM
from sklearn.svm import SVC
clf = SVC(kernel = 'rbf', gamma = 1.5,C = 2,max_iter=1000).fit(X_train, y_train)
print('Training Score:',clf.score(X_train,y_train))
print('Testing Score:',clf.score(X_test,y_test))
# Out:
# Training Score: 1.0
# Testing Score: 1.0

# %%
y_pred=clf.predict(X_test)
print(classification_report(y_test,y_pred))
confusion_mc = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(confusion_mc)
plt.figure(figsize=(15,8))
sea.heatmap(df_cm, annot=True)
plt.ylabe='True label'
plt.xlabel='Predicted label'
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        26
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58

# %%
clf = SVC(kernel = 'rbf', gamma = 1.5,C = 20,max_iter=1000).fit(X_train, y_train)
print('Training Score:',clf.score(X_train,y_train))
print('Testing Score:',clf.score(X_test,y_test))
# Out:
# Training Score: 1.0
# Testing Score: 1.0

# %%
import pickle
filename = 'kidney_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
from sklearn.tree import DecisionTreeRegressor 
regressor = DecisionTreeRegressor(random_state = 1) 
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print('Accuracy  on train set:' , regressor.score(X_train, y_train))
print('Accuracy  on test set:' , regressor.score(X_test, y_test))
# Out:
# Accuracy  on train set: 1.0
# Accuracy  on test set: 0.9302884615384616

# %%
clf = SVC(kernel = 'rbf', gamma = 100,C = 2,max_iter=1000).fit(X_train, y_train)
print('Training Score:',clf.score(X_train,y_train))
print('Testing Score:',clf.score(X_test,y_test))
# Out:
# Training Score: 1.0
# Testing Score: 0.9137931034482759

# %%
y_pred=clf.predict(X_test)
print(classification_report(y_test,y_pred))
confusion_mc = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(confusion_mc)
plt.figure(figsize=(15,8))
sea.heatmap(df_cm, annot=True)
plt.ylabe='True label'
plt.xlabel='Predicted label'
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92        32
#            1       0.84      1.00      0.91        26
#
#     accuracy                           0.91        58
#    macro avg       0.92      0.92      0.91        58
# weighted avg       0.93      0.91      0.91        58

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, plot_confusion_matrix

pipeline = make_pipeline(StandardScaler(), RandomForestClassifier())
pipeline.fit(X_train, y_train)
prediction = pipeline.predict(X_test)

print(f"Accuracy Score : {round(accuracy_score(y_test, prediction) * 100, 2)}%")
# Out:
# Accuracy Score : 100.0%

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        26
#
#     accuracy                           1.00        58
#    macro avg       1.00      1.00      1.00        58
# weighted avg       1.00      1.00      1.00        58

# %%
plot_confusion_matrix(pipeline, X_test, y_test)
plt.grid(False)
plt.show()
# Out:
# C:\Users\Fawaz_Tujjar\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
